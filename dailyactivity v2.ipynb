# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dailyActivity_merged.csv')

# %%
df.shape
# Out:
# (457, 15)

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   25/03/2016     11004.0           7.11             7.11
# 1  1503960366   26/03/2016     17609.0          11.55            11.55
# 2  1503960366   27/03/2016     12736.0           8.53             8.53
# 3  1503960366   28/03/2016     13231.0           8.93             8.93
# 4  1503960366   29/03/2016     12041.0           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 452  8877689391   08/04/2016     23014.0          20.39            20.39
# 453  8877689391   09/04/2016     16470.0           8.07             8.07
# 454  8877689391   10/04/2016     28497.0          27.53            27.53
# 455  8877689391   11/04/2016     10622.0           8.06             8.06
# 456  8877689391   12/04/2016      2350.0           1.78             1.78
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    float64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
df['ActivityDate']=df['ActivityDate'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    datetime64[ns]
#  2   TotalSteps                457 non-null    float64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
pd.isnull(df)
# Out:
#         Id  ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    False         False       False          False            False
# 1    False         False       False          False            False
# 2    False         False       False          False            False
# 3    False         False       False          False            False
# 4    False         False       False          False            False
# ..     ...           ...         ...            ...              ...
# 452  False         False       False          False            False
# 453  False         False       False          False            False
# 454  False         False       False          False            False
# 455  False         False       False          False            False
# 456  False         False       False          False            False
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
pd.isnull(df).sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.shape
# Out:
# (457, 15)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (457, 15)

# %%
df.describe()
# Out:
#                  Id                   ActivityDate    TotalSteps  \
# count  4.570000e+02                            457    457.000000
# mean   4.628595e+09  2016-05-28 17:48:11.028446464   6546.562363
# min    1.503960e+09            2016-01-04 00:00:00      0.000000
# 25%    2.347168e+09            2016-03-18 00:00:00   1988.000000
# 50%    4.057193e+09            2016-05-04 00:00:00   5986.000000
# 75%    6.391747e+09            2016-08-04 00:00:00  10198.000000
# max    8.877689e+09            2016-12-04 00:00:00  28497.000000
# std    2.293781e+09                            NaN   5398.493064
#
#        TotalDistance  TrackerDistance  LoggedActivitiesDistance  \
# count     457.000000       457.000000                457.000000
# mean        4.663523         4.609847                  0.179427
# min         0.000000         0.000000                  0.000000
# 25%         1.410000         1.280000                  0.000000
# ...

# %%
df[['TotalSteps','TotalDistance','Calories']].describe()
# Out:
#          TotalSteps  TotalDistance     Calories
# count    457.000000     457.000000   457.000000
# mean    6546.562363       4.663523  2189.452954
# std     5398.493064       4.082072   815.484523
# min        0.000000       0.000000     0.000000
# 25%     1988.000000       1.410000  1776.000000
# 50%     5986.000000       4.090000  2062.000000
# 75%    10198.000000       7.160000  2667.000000
# max    28497.000000      27.530000  4562.000000

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
ax=sns.lineplot(x='Calories',y='TotalDistance',data=df)
plt.title('Calories vs Total Distance')
plt.xlabel('Calories')
plt.ylabel('Total Distance')
plt.show()
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize=(8,6))
sns.set(style='whitegrid')
ax=sns.scatterplot(x='Calories',y='TotalSteps',data=df,hue='TotalSteps')
plt.title('Calories vs Total steps')
plt.xlabel('calories')
plt.ylabel('Total steps')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set(style='whitegrid')
ax=sns.regplot(x='Calories',y='TotalSteps',data=df,scatter_kws={'alpha':0.5},line_kws={'color':'red'})
plt.xlabel('Calories')
plt.ylabel('Totsl Steps')
plt.title('Calories vs Total steps')
plt.show()

# %% [markdown]
# This plot suggest taht more steps = more calories burned

# %% [markdown]
# This graph show how there is a positive trend in the calories and total steps taken relationship,here each dot discribe a day or the time where data was taken and the red line show us how calories and total steps are related this is shoing a positive trend and the line is moving upward the blue dots on the line are the correct values or normal values and the blue dots far from the red line are unusual data points or the days where calorie count are unexpectedly high or low for the number of steps taken

# %%
sns.set(style='whitegrid')
distance_types = ['VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance']

plt.figure(figsize=(18, 5))

for i, dist in enumerate(distance_types):
    plt.subplot(1, 3, i + 1)
    sns.regplot(x=dist, y='Calories', data=df,scatter_kws={'alpha': 0.5},line_kws={'color': 'red'})
    plt.title('Calories vs ' + dist)
    plt.xlabel(dist)
plt.show()

# %% [markdown]
# This plot show how diffent distance effect calories

# %%
df['WeekDays']=df['ActivityDate'].dt.day_name()
sns.set(style='whitegrid')
plt.figure(figsize=(8,5))
ax=sns.barplot(x='WeekDays',y='Calories',data=df,color='red',order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.xlabel('weekdays')
plt.ylabel('Calories')
plt.title('calories vs weekdays')
plt.show()

# %% [markdown]
# this shows the calories burned on each day of the week .This also shows on which days of the week the users are readily active

# %%
ActiveMinutes=df[['VeryActiveMinutes', 'FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']]
AverageTime=ActiveMinutes.mean()
sns.set(style='whitegrid')
plt.figure(figsize=(9,5))
ax=sns.barplot(x=AverageTime.index,y=AverageTime.values)
plt.xlabel('Active Minutes')
plt.ylabel('Average Minutes')
plt.title('Average Active Minutes')
plt.show()

# %% [markdown]
# This shows us how much time user spents doing exercide where very active means intense excercise and sedentary minutes means that the user is inactive or resting

# %% [markdown]
# so by tthis we can say that people are spending much time inactive than dooing some activity or some excercise
